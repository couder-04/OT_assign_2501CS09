# %% [markdown]
# # Optimization Techniques Assignment
#
# 1. **Big-M Simplex Method** for a mixed-constraint LPP
# 2. **Transportation problem** using **VAM** then **MODI**
#
# Run each code cell and screenshot the cell (code) together with its output for the submitted PDF.

# %% [markdown]
# ## 1. Big-M Method
#
# Minimize $Z = 4x_1 + x_2$ subject to
# $3x_1 + x_2 = 3$,
# $4x_1 + 3x_2 \ge 6$,
# $x_1 + 2x_2 \le 4$,
# $x_1, x_2 \ge 0$.
#
# Converted to standard form with slack, surplus and artificial variables, then solved by Big-M simplex.

# %%
from big_m_method import main as big_m_main
big_m_main()
# Out:
# ASSIGNMENT  —  BIG-M SIMPLEX METHOD
#
# ...
# ORIGINAL LINEAR PROGRAMMING PROBLEM
# ...
#     MINIMIZE  Z = 4x1 + x2
#     subject to
#         3x1 + x2  =  3
#         4x1 + 3x2  >=  6
#         x1 + 2x2  <=  4
#         x1, x2  >=  0
#
# ...
# STANDARD FORM  (slack / surplus / artificial variables)
# ...
#   Slack    (s): added to  <=  constraints
#   Surplus  (p): subtracted from  >=  constraints
#   Artificial(a): added to  >=  and  =  constraints
#
#   Big-M objective (MIN):  Z = original cost  +  M * (sum of artificials)
#
#     3x1 + x2 + a1  =  3
#     4x1 + 3x2 - p1 + a2  =  6
#     x1 + 2x2 + s1  =  4
#
#   Artificial variables: a1, a2
#   Initial basis:        a1, a2, s1
#
# ...
# BIG-M SIMPLEX ITERATIONS
# ...
#   Optimality test:
#     MIN problem — stop when every (cj - zj) >= 0
#     Entering variable: most negative (cj - zj)
#     Leaving variable:  minimum non-negative RHS / pivot-column ratio
#
# SIMPLEX TABLEAU  —  Iteration 0    (current Z = 9M)
# ...

# %% [markdown]
# ## 2. Transportation Problem
#
# Factories $F_1,F_2,F_3$ to warehouses $W_1,W_2,W_3,W_4$. Unit costs, supplies and demands:
#
# |  | W1 | W2 | W3 | W4 | Supply |
# |---|---|---|---|---|---|
# | F1 | 19 | 30 | 50 | 10 | 7 |
# | F2 | 70 | 30 | 40 | 60 | 9 |
# | F3 | 40 | 8 | 70 | 20 | 18 |
# | Demand | 5 | 8 | 7 | 14 | 34 |
#
# **(i)** Vogel's Approximation Method — initial basic feasible solution
# **(ii)** MODI — optimality test and improvement (run separately, one method at a time)

# %% [markdown]
# ### (i) Vogel's Approximation Method (VAM)

# %%
from transportation import main as transport_main
transport_main("vam")

# %% [markdown]
# ### (ii) MODI (Modified Distribution) Method
#
# Starts from the VAM initial basic feasible solution, tests optimality, and improves the allocation.

# %%
from transportation import main as transport_main
transport_main("modi")
